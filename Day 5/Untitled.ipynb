# %%
import pandas as pd

# %%
# reading the csv file
df_exams=pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1. Selecting one column

# %% [markdown]
# ## 1.1 Syntax 1

# %%
# select a column with [] (preferred way to select a column)
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# check out the data type of a column 
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# series: attributes and methods 
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# series: attributes and methods 
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ## 1.2 Syntax 2

# %%
# select a column with .
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# select a column with . (pitfalls)
df_exams.math score
# Out:
#   Cell In[9], line 2
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %%
# select the same column using []
df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# # 2. Selecting two or more columns

# %%
# select 2 column using [[]]
df_exams[['gender' , 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# check out the data type of the selection
type(df_exams[['gender' , 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# seelct 2 or more colums using [[]]
df_exams[['gender' , 'math score' , 'reading score' , 'writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %%
# we can't select 2 or more columns with the "."
df_exams.'gender' , 'math score'
# Out:
#   Cell In[16], line 2
#     df_exams.'gender' , 'math score'
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 3. Add new column to a dataframe

# %% [markdown]
# # 1. Adding a new column with scalar value

# %% [markdown]
# ### 3.1 Adding a new column with a scalar value

# %%
# adding new column to dataframe
df_exams['language score'] = 70

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### 3.2 Adding a new column with an array

# %%
# the dataframe has 1000 rows , so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 1000 elememts
language_score = np.arange(0, 1000)

# %%
len(language_score)
# Out:
# 1000

# %%
# adding a new column to dataframe with an array
df_exams['language_score'] = language_score

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score
# 0                70               0
# 1                70               1
# 2                70               2
# 3                70               3
# 4                70               4
# ..              ...             ...
# 995              70             995
# 996              70             996
# 997              70             997
# 998              70             998
# 999              70             999
#
# [1000 rows x 10 columns]

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1,100,size=1000)

# %%
# min value (it is inclusive)
min(int_language_score)
# Out:
# np.int32(1)

# %%
# max value (it is exclusive)
max(int_language_score)
# Out:
# np.int32(99)

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score
# 0                59               0
# 1                59               1
# 2                42               2
# 3                90               3
# 4                47               4
# ..              ...             ...
# 995              67             995
# 996              95             996
# 997               8             997
# 998              20             998
# 999               8             999
#
# [1000 rows x 10 columns]

# %%
# create random float numbers between 1 and 100
np.random.uniform(1,100,size=100)
# Out:
# array([19.90920433, 78.31106223, 89.08885495, 53.19319614, 71.54767275,
#        40.4065396 , 22.59928877, 95.16018744, 20.92157217, 93.09498424,
#         8.42579286, 73.36187948, 71.17952224, 80.62947479, 65.458954  ,
#        87.06015679, 56.62956211, 71.18745481,  6.74970566, 41.48853758,
#        61.26285853, 12.84565685, 22.42987049, 98.91341589, 81.38085138,
#        57.97316199, 47.87576552,  6.26395404, 44.48597209, 15.82142914,
#        75.23242239, 43.94580718, 21.28756921, 16.90966429, 92.34863715,
#        75.27666453, 34.88012872, 13.12461673, 54.03226963, 10.03460343,
#        63.37485707, 34.14956414, 11.20945195, 66.64510766, 65.14224973,
#        84.91557964, 98.61258199, 88.55488153, 50.19792652, 57.74120945,
#        46.10072054, 14.87392633, 92.87985629, 93.30675324, 33.72769518,
#        11.66564569, 35.20258532, 55.69106708, 66.86688468, 99.05052019,
#         1.75296748, 95.88854519, 82.95103306, 26.034324  , 51.8490822 ,
#        14.53266735, 55.95158967, 87.54868918, 26.1651613 , 90.96019672,
#        57.52848228, 87.41666158, 44.69857561, 84.60860857, 52.38528424,
#        22.09964662, 85.81132483,  3.13362078, 98.48548036,  9.12321881,
#        89.96242776, 25.66642477, 73.14205348, 24.79648234, 78.52606583,
#        20.5025618 , 96.92668442, 52.61086647,  7.30841212, 51.85221901,
#         4.93445368, 78.74023565, 34.43946317, 25.34331853, 29.98714344,
#        16.72682747, 69.74991519, 48.73782156, 63.74980018, 86.05142921])

# %% [markdown]
# # 4. Add New Column with assign() and insert()

# %% [markdown]
# ## 1. Adding a new column

# %% [markdown]
# ### 4.1 assign()

# %%
# When to use assign()?
#-> Add multiple columns in a single line of code
#-> When you need to overwrite the values of an existing columns(best practice)

#It returns a new object(a copy) with all the original columns in addition to the new one

# %%
import numpy as np

# %%
# create ramdom numbers for our new score columns
score1=np.random.randint(1,100,size=1000)
score2=np.random.randint(1,100,size=1000)

# %%
# create a series using the random numbers
series1=pd.Series(score1,index=np.arange(0,1000))
series2=pd.Series(score2,index=np.arange(0,1000))

# %%
# using assign() to add multiple columns
df_exams= df_exams.assign(score1=series1 , score2=series2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score  score1  score2
# 0                59               0      28      80
# 1                59               1      16      44
# 2                42               2      28      89
# 3                90               3      38      52
# 4                47               4      24      34
# ..              ...             ...     ...     ...
# 995              67             995      39      41
# 996              95             996      93      80
# 997               8             997      80      90
# 998              20             998      51      85
# 999               8             999      19       8
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### 4.2 insert()

# %%
# inserts a new column at a specific position or index
# does not create a copy but changes the actual

# %%
# using index() to add a column at a specific position
df_exams.insert(1,'test',series1)

# %%
# show dataframe
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    28        group B           bachelor's degree      standard
# 1    female    16        group C                some college      standard
# 2    female    28        group B             master's degree      standard
# 3      male    38        group A          associate's degree  free/reduced
# 4      male    24        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    39        group E             master's degree      standard
# 996    male    93        group C                 high school  free/reduced
# 997  female    80        group C                 high school  free/reduced
# 998  female    51        group D                some college      standard
# 999  female    19        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score  score1  score2
# 0                59               0      28      80
# 1                59               1      16      44
# 2                42               2      28      89
# 3                90               3      38      52
# 4                47               4      24      34
# ..              ...             ...     ...     ...
# 995              67             995      39      41
# 996              95             996      93      80
# 997               8             997      80      90
# 998              20             998      51      85
# 999               8             999      19       8
#
# [1000 rows x 13 columns]
