# %%
import pandas as pd

# %%
# reading and showing dataframe
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 1. Create Index

# %%
import numpy as np
import random

# %%
# creating non-reptitive values for the index
new_index = np.arange(0,1000)

# %%
# shuffling the indexes
random.shuffle(new_index)
new_index
# Out:
# array([998, 704, 844,  41, 175, 872, 610, 243, 589, 513, 909, 260, 445,
#        278, 212, 662, 563, 429, 329, 889,  44, 236, 270, 480, 635,  92,
#        416, 440, 343, 106, 749, 524,   7,   5, 621, 147, 943, 315, 705,
#        720, 143, 229, 342, 894, 436, 620, 794, 348, 591, 802, 168, 449,
#        712, 362, 772, 491, 256, 372, 368, 598, 253, 797, 384, 702, 646,
#        669, 686, 593, 915, 370, 806, 699, 982, 857, 309,  24,  26, 237,
#        768,  51, 205, 804, 169,  82, 289, 744, 533, 163, 967, 506, 774,
#        813, 895, 739, 743, 431, 899, 643, 125, 215, 751, 502, 972,  91,
#        357, 134, 927, 123, 609, 556, 181, 599, 571, 308, 729, 478, 453,
#        324, 561, 160, 737, 906, 562, 716, 114, 412, 437, 223, 541, 331,
#        326, 543, 408, 264, 468, 173, 791,  46, 919, 765, 196, 432, 892,
#        580, 378, 718, 925, 940, 871, 246, 350, 963, 132, 795,  77, 301,
#        740,  67, 642, 103, 878, 146, 325, 307, 197, 544, 183,  72, 822,
#        826, 259, 719,  83, 296, 956, 590, 295, 360, 884, 233, 207,  18,
#        479, 846, 148, 829, 341, 456, 981, 886, 836,  74, 933,  21, 674,
#        664, 113, 124, 881, 320, 487, 730, 678, 393, 877, 135, 648, 527,
#        615, 546, 602, 638, 827, 178, 780, 788, 213, 266, 219,  59, 185,
#         40, 523, 419, 512, 803, 627, 170, 616, 269, 211,  53, 758, 531,
#         39, 782, 371, 504, 465, 592, 847, 327, 399, 435,  64, 292, 353,
#        766,  90, 528, 989, 888, 306, 742, 995, 851, 287,  38, 625, 220,
#        550, 652, 508, 496, 189, 569, 464, 875, 254, 960, 161, 644, 361,
#        841, 975,  58, 116, 980, 102, 109, 612,  33,  85, 403, 558, 675,
#        241, 514, 498,  10, 511, 495,  45, 692, 268, 696, 908, 763, 322,
#        869, 318, 457, 820, 862, 294, 731, 424, 149, 760,  54,  62, 586,
#        557, 305, 701, 426, 613, 400, 631, 684, 380, 190,  35, 444, 159,
#        993, 976, 713, 415, 355, 930, 656, 107, 249,  22, 681, 757, 549,
#        167, 339, 914,  96, 840, 912, 328, 420, 105, 697, 781, 997, 852,
#        500, 838, 799, 624, 317, 346, 154, 198, 770, 953, 313, 987, 859,
#        284, 128, 238, 110, 242, 121, 848, 777, 832, 966, 129,  15, 948,
#        905, 870, 172, 660, 831, 383, 421, 334, 497, 973, 748,  88, 661,
#        903, 745, 896, 921, 796, 152, 950, 691, 534, 425, 312, 239, 568,
#        369,  30, 968, 462, 706, 536, 938, 650, 554, 180, 849, 657, 482,
#        653, 816, 955, 732, 567, 310, 443, 501, 164, 576, 655, 572, 645,
#        756, 471, 775, 319,  57,  79, 199, 323, 945, 423, 917, 351, 584,
#        288, 122,   4, 285, 746, 647, 330,  86, 942, 162, 364,  28, 448,
#        451, 476, 928, 250, 427, 470, 338, 516, 174, 171, 629, 141, 665,
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 998        female        group B           bachelor's degree      standard
# 704        female        group C                some college      standard
# 844        female        group B             master's degree      standard
# 41           male        group A          associate's degree  free/reduced
# 175          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 293        female        group E             master's degree      standard
# 283          male        group C                 high school  free/reduced
# 32         female        group C                 high school  free/reduced
# 868        female        group D                some college      standard
# 898        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score  \
# new_index
# 998                          none          72             72             74
# 704                     completed          69             90             88
# 844                          none          90             95             93
# 41                           none          47             57             44
# 175                          none          76             78             75
# ...                           ...         ...            ...            ...
# 293                     completed          88             99             95
# 283                          none          62             55             55
# 32                      completed          59             71             65
# 868                     completed          68             78             77
# 898                          none          77             86             86
#
#            new_index
# new_index
# 998              998
# 704              704
# 844              844
# 41                41
# 175              175
# ...              ...
# 293              293
# 283              283
# 32                32
# 868              868
# 898              898
#
# [1000 rows x 9 columns]

# %% [markdown]
# # 2.Set index

# %%
# set new_index column as index
df_exams.set_index('new_index', inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 998        female        group B           bachelor's degree      standard
# 704        female        group C                some college      standard
# 844        female        group B             master's degree      standard
# 41           male        group A          associate's degree  free/reduced
# 175          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 293        female        group E             master's degree      standard
# 283          male        group C                 high school  free/reduced
# 32         female        group C                 high school  free/reduced
# 868        female        group D                some college      standard
# 898        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 998                          none          72             72             74
# 704                     completed          69             90             88
# 844                          none          90             95             93
# 41                           none          47             57             44
# 175                          none          76             78             75
# ...                           ...         ...            ...            ...
# 293                     completed          88             99             95
# 283                          none          62             55             55
# 32                      completed          59             71             65
# 868                     completed          68             78             77
# 898                          none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 3.Sort Index

# %%
# sort dataframe by new index
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0            male        group C                 high school      standard
# 1          female        group D             master's degree      standard
# 2          female        group A                 high school      standard
# 3          female        group A                 high school      standard
# 4            male        group A            some high school  free/reduced
# ...           ...            ...                         ...           ...
# 995          male        group D                 high school      standard
# 996        female        group E                some college      standard
# 997          male        group E          associate's degree      standard
# 998        female        group B           bachelor's degree      standard
# 999          male        group C           bachelor's degree  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                            none          90             75             69
# 1                            none          78             91             96
# 2                       completed          75             82             79
# 3                            none          55             73             73
# 4                            none          79             82             73
# ...                           ...         ...            ...            ...
# 995                          none          54             52             52
# 996                     completed          86             85             91
# 997                          none          87             74             76
# 998                          none          72             72             74
# 999                     completed          70             75             74
#
# [1000 rows x 8 columns]

# %%
# sort descending by index
df_exams.sort_index(ascending=False,inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group C           bachelor's degree  free/reduced
# 998        female        group B           bachelor's degree      standard
# 997          male        group E          associate's degree      standard
# 996        female        group E                some college      standard
# 995          male        group D                 high school      standard
# ...           ...            ...                         ...           ...
# 4            male        group A            some high school  free/reduced
# 3          female        group A                 high school      standard
# 2          female        group A                 high school      standard
# 1          female        group D             master's degree      standard
# 0            male        group C                 high school      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 999                     completed          70             75             74
# 998                          none          72             72             74
# 997                          none          87             74             76
# 996                     completed          86             85             91
# 995                          none          54             52             52
# ...                           ...         ...            ...            ...
# 4                            none          79             82             73
# 3                            none          55             73             73
# 2                       completed          75             82             79
# 1                            none          78             91             96
# 0                            none          90             75             69
#
# [1000 rows x 8 columns]
